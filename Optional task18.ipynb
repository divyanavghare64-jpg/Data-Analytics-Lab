# %%
# Q1. Import Required Libraries

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
# Q2. Load Dataset

df = pd.read_csv("/content/insurance.csv")

print("First 5 Rows:")
print(df.head())
# Out:
# First 5 Rows:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# Q3. Dataset Information

print("Shape:", df.shape)
print(df.info())
print(df.describe())
# Out:
# Shape: (1337, 7)
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   float64
#  1   sex       1337 non-null   int64
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   float64
#  4   smoker    1337 non-null   int64
#  5   region    1337 non-null   int64
#  6   expenses  1337 non-null   float64
# dtypes: float64(4), int64(3)
# memory usage: 83.6 KB
# None
#                age          sex          bmi     children       smoker  \
# count  1337.000000  1337.000000  1337.000000  1337.000000  1337.000000
# mean      0.001076     0.504862     0.000008     0.000680     0.204936
# std       0.999973     0.500163     1.000748     1.000439     0.403806
# min      -1.509965     0.000000    -2.405713    -0.908614     0.000000
# 25%      -0.869155     0.000000    -0.716108    -0.908614     0.000000
# 50%      -0.014740     1.000000    -0.043548    -0.078767     0.000000
# 75%       0.839674     1.000000     0.661821     0.751079     0.000000
# max       1.765289     1.000000     3.680143     3.240619     1.000000
#
#             region     expenses
# count  1337.000000  1337.000000
# mean      1.516081     0.000719
# std       1.105208     1.000403
# min       0.000000    -1.003558
# 25%       1.000000    -0.704150
# 50%       2.000000    -0.320868
# 75%       2.000000     0.279815
# max       3.000000     4.171663

# %%
# Q4. Check Missing Values

print(df.isnull().sum())
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
 # Q5. Check Duplicate Rows

print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
# Q6. Remove Duplicate Rows

df = df.drop_duplicates()

print("New Shape:", df.shape)
# Out:
# New Shape: (1337, 7)

# %%
# Q7. Check Invalid Values

print((df[['age','bmi','children','expenses']] < 0).sum())
# Out:
# age         674
# bmi         692
# children    898
# expenses    918
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
# Q8. Encode Categorical Columns

le = LabelEncoder()

df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

print(df.head())
# Out:
#         age  sex       bmi  children  smoker  region  expenses
# 0 -1.438764    0 -0.453646 -0.908614       1       3  0.298583
# 1 -1.509965    1  0.514186 -0.078767       0       2 -0.953689
# 2 -0.797954    1  0.382954  1.580926       0       2 -0.728675
# 3 -0.441948    1 -1.306650 -0.908614       0       1  0.719843
# 4 -0.513149    1 -0.289606 -0.908614       0       1 -0.776802

# %%
# Q9. Feature Scaling

scaler = StandardScaler()

cols = ['age','bmi','children','expenses']

df[cols] = scaler.fit_transform(df[cols])

print(df.head())
# Out:
#         age     sex       bmi  children smoker     region  expenses
# 0 -1.438764  female -0.453646 -0.908614    yes  southwest  0.298583
# 1 -1.509965    male  0.514186 -0.078767     no  southeast -0.953689
# 2 -0.797954    male  0.382954  1.580926     no  southeast -0.728675
# 3 -0.441948    male -1.306650 -0.908614     no  northwest  0.719843
# 4 -0.513149    male -0.289606 -0.908614     no  northwest -0.776802

# %%
# Q10. Outlier Detection & Removal

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)

IQR = Q3 - Q1

df = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

print("Shape After Removing Outliers:", df.shape)
# Out:
# Shape After Removing Outliers: (1054, 7)

# %%
# Q11. Save Cleaned Dataset

df.to_csv("insurance_cleaned.csv", index=False)

print("Dataset Saved Successfully.")
# Out:
# Dataset Saved Successfully.

# %%
# Q12. Display Final Dataset

print(df.head())
# Out:
#         age  sex       bmi  children  smoker  region  expenses
# 1 -1.509965    1  0.514186 -0.078767       0       2 -0.953689
# 2 -0.797954    1  0.382954  1.580926       0       2 -0.728675
# 3 -0.441948    1 -1.306650 -0.908614       0       1  0.719843
# 4 -0.513149    1 -0.289606 -0.908614       0       1 -0.776802
# 5 -0.584350    0 -0.814532 -0.908614       0       2 -0.785908
