# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("insurance.csv")

# %%
df.head(10)
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59
# 7   37  female  27.7         3     no  northwest   7281.51
# 8   37    male  29.8         2     no  northeast   6406.41
# 9   60  female  25.8         0     no  northwest  28923.14

# %%
print("Shape:", df.shape)
# Out:
# Shape: (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
num_cols = df.select_dtypes(include=['int64','float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

print("Numerical Columns:")
print(num_cols)

print("\nCategorical Columns:")
print(cat_cols)
# Out:
# Numerical Columns:
# Index(['age', 'bmi', 'children', 'expenses'], dtype='object')
#
# Categorical Columns:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))

for i, col in enumerate(num_cols, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(5,4))
    sns.countplot(x=df[col])
    plt.title(f"Count Plot of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
print(df.columns)
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
print("Average Expenses:", df["expenses"].mean())

print("Maximum Expenses:", df["expenses"].max())

print("Minimum Expenses:", df["expenses"].min())

print(df.groupby("smoker")["expenses"].mean())
# Out:
# Average Expenses: 13270.422414050823
# Maximum Expenses: 63770.43
# Minimum Expenses: 1121.87
# smoker
# no      8434.268449
# yes    32050.231971
# Name: expenses, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,5))
sns.boxplot(x="smoker", y="expenses", data=df)
plt.show()

plt.figure(figsize=(6,5))
sns.boxplot(x="sex", y="expenses", data=df)
plt.show()

# %%
# Analysis Summary

1. From the dataset, I observed that the average age of customers is around 39 years and the average BMI is around 30.

2. After comparing smokers and non-smokers, I found that smokers have much higher insurance expenses.

3. By checking the region count plot, I observed that the Southeast region has the highest number of customers.

4. From the visualizations, I noticed that most customers have BMI between 25 and 35, and insurance expenses are much higher for smokers. Age also has some effect on expenses.=-
